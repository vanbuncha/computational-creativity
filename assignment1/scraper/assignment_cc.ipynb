# %%
# ! conda install numpy pandas tensorflow transformers nltk 
# ! conda install requests beautifulsoup4 pandas

# %% [markdown]
# # Log of my thought process
# - First I was deciding between which kinda of poem generator i want to use - Template based, Markov Chain, Dust House etc.
# - Decided that those mentioned were not interesting enough
# - Chose neural networks
# - It was time to decide what kind of poems to use as inspiration
# - Remembered Charles Bukowski because of his strong and recognizable style of writing - struggle of living life
# - scraped Poem Hunter - 151 Bukowski poems - not enough (imo) so scraped some more similar authors (Allen Ginsberg, Jack Kerouac, Lawrence Felinghetti and Sylvia Plath)
# - joined scraped data and cleaned it up
# - created tokenizer and fined tuned gpt2
# - then for poem generation i played around few parameters - especially giving model freedom of how long poem can be to not have abrupt end. Seed initialiation, temperature etc
# - Also seed text has big influence - can inflence the stylistical style a lot
# - poem make sense but have no sentence stoppers
# - as for evaluation i fed back poems to Chatgpt to try to guess who is the author - usually at least one of the chosen authors sometimes 3/5 or even 4/5.
# - sometimes guessed some other authors as well: William S. Burroughs, T.S. Eliot occuring a lot

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import time
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import nltk
nltk.download('punkt')  # Download data for NLTK tokenization


import requests
from bs4 import BeautifulSoup
import re
# Out:
# [nltk_data] Downloading package punkt to /Users/vanbuncha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Scraping poem authors
# Charles Bukowski as main focus
# and another 4 authors - Allen Ginsberg, Jack Kerouac, Lawrence Ferlinghetti, Sylvia Plath

# %%
# Dictionary of poets and their base URLs with the number of pages to scrape
poets = {
    'charles_bukowski': ("https://www.poemhunter.com/charles-bukowski/poems/page-{}/", 16),
    'allen_ginsberg': ("https://www.poemhunter.com/allen-ginsberg/poems/page-{}/", 5),  
    'jack_kerouac': ("https://www.poemhunter.com/jack-kerouac/poems/page-{}/", 3),     
    'lawrence_ferlinghetti': ("https://www.poemhunter.com/lawrence-ferlinghetti/poems/page-{}/", 4),
    'sylvia_plath': ("https://www.poemhunter.com/sylvia-plath/poems/page-{}/", 25)
}

# Loop through each poet in the dictionary
for poet, (base_url, num_pages) in poets.items():
    print(f"Scraping poems by {poet.replace('_', ' ').title()}...")
    
    # lists to store titles and links
    all_poem_titles = []
    all_poem_links = []

    # loop through all pages
    for page_number in range(1, num_pages + 1):
        print(f"Scraping page {page_number} of {num_pages} for {poet.replace('_', ' ').title()}...")


        page_url = base_url.format(page_number)
        response = requests.get(page_url)
        soup = BeautifulSoup(response.text, 'html.parser')


        poem_elements = soup.find_all('div', class_='phlText')

        # if no poem elements are found, we've reached the last page
        if not poem_elements:
            print(f"No poems found on page {page_number}. Ending scrape.")
            break

        # extract links and titles for each poem on the current page
        for poem_element in poem_elements:
            link = poem_element.find('a')
            if link:
                all_poem_titles.append(link.text.strip())  # Store poem title
                all_poem_links.append("https://www.poemhunter.com" + link['href'])  # Store complete poem URL

        # add a short delay to avoid overloading the server
        time.sleep(1)

    # visit each poem page
    all_poem_texts = []

    for idx, poem_link in enumerate(all_poem_links):
        poem_response = requests.get(poem_link)
        poem_soup = BeautifulSoup(poem_response.text, 'html.parser')

        # extract the poem content from the specific div
        poem_div = poem_soup.find('div', class_='phContent phcText')
        if poem_div:
            poem_text = poem_div.get_text(separator="\n", strip=True) 
            all_poem_texts.append(poem_text)
        else:
            all_poem_texts.append("")  # If no poem text is found, append an empty string

        # Print progress
        print(f"Scraped {idx + 1}/{len(all_poem_links)}: {all_poem_titles[idx]}")

        # add a short delay to avoid overwhelming the server
        time.sleep(1)

    # save all collected poems to a CSV file
    poems_df = pd.DataFrame({'Title': all_poem_titles, 'Content': all_poem_texts})
    csv_filename = f'{poet}_poems.csv'
    poems_df.to_csv(csv_filename, index=False, encoding='utf-8')

    print(f"Scraping completed for {poet.replace('_', ' ').title()}! Poems saved to '{csv_filename}'.")

print("All poets have been scraped successfully!")
# Out:
# Scraping poems by Charles Bukowski...
# Scraping page 1 of 16 for Charles Bukowski...
# Scraping page 2 of 16 for Charles Bukowski...
# Scraping page 3 of 16 for Charles Bukowski...
# Scraping page 4 of 16 for Charles Bukowski...
# Scraping page 5 of 16 for Charles Bukowski...
# Scraping page 6 of 16 for Charles Bukowski...
# Scraping page 7 of 16 for Charles Bukowski...
# Scraping page 8 of 16 for Charles Bukowski...
# Scraping page 9 of 16 for Charles Bukowski...
# Scraping page 10 of 16 for Charles Bukowski...
# Scraping page 11 of 16 for Charles Bukowski...
# Scraping page 12 of 16 for Charles Bukowski...
# Scraping page 13 of 16 for Charles Bukowski...
# Scraping page 14 of 16 for Charles Bukowski...
# Scraping page 15 of 16 for Charles Bukowski...
# Scraping page 16 of 16 for Charles Bukowski...
# Scraped 1/151: A Smile To Remember
# Scraped 2/151: Alone With Everybody
# Scraped 3/151: An Almost Made Up Poem
# Scraped 4/151: And The Moon And The Stars And The World
# Scraped 5/151: Bluebird
# Scraped 6/151: A Challenge To The Dark
# Scraped 7/151: Be Kind
# Scraped 8/151: Let It Enfold You
# Scraped 9/151: Are You Drinking?
# Scraped 10/151: As The Sparrow
# Scraped 11/151: Cause And Effect
# Scraped 12/151: A Radio With Guts
# Scraped 13/151: The Genius Of The Crowd
# Scraped 14/151: As The Poems Go
# Scraped 15/151: Confession
# Scraped 16/151: Back To The Machine Gun
# Scraped 17/151: Consummation Of Grief
# Scraped 18/151: Carson Mccullers
# Scraped 19/151: 40,000
# Scraped 20/151: A Following
# Scraped 21/151: Big Night On The Town
# Scraped 22/151: Close To Greatness
# Scraped 23/151: Yes Yes
# Scraped 24/151: To The Whore Who Took My Poems
# Scraped 25/151: 2 Flies
# Scraped 26/151: Raw With Love
# Scraped 27/151: Cows In Art Class
# Scraped 28/151: Girl In A Miniskirt Reading The Bible Outside My Window
# Scraped 29/151: Eulogy To A Hell Of A Dame
# Scraped 30/151: Finish
# Scraped 31/151: Death Wants More Death
# Scraped 32/151: Pull A String, A Puppet Moves
# Scraped 33/151: Friends Within The Darkness
# Scraped 34/151: Curtain
# Scraped 35/151: For Jane
# Scraped 36/151: Eat Your Heart Out
# Scraped 37/151: Nirvana
# Scraped 38/151: 8 Count
# Scraped 39/151: 16-Bit Intel 8088 Chip
# Scraped 40/151: I Met A Genius
# Scraped 41/151: Whats The Use Of A Title?
# Scraped 42/151: Oh Yes
# Scraped 43/151: For Jane: With All The Love I Had, Which Was Not Enough:
# Scraped 44/151: Freedom
# Scraped 45/151: About My Very Tortured Friend, Peter
# Scraped 46/151: Decline
# Scraped 47/151: The Aliens
# Scraped 48/151: How Is Your Heart?
# Scraped 49/151: Cut While Shaving
# Scraped 50/151: We Ain'T Got No Money, Honey, But We Got Rain
# Scraped 51/151: Sway With Me
# Scraped 52/151: I'm In Love
# Scraped 53/151: Flophouse
# Scraped 54/151: I Made A Mistake
# Scraped 55/151: True
# Scraped 56/151: Having The Flu And With Nothing Else To Do
# Scraped 57/151: Some People
# Scraped 58/151: Rhyming Poem
# Scraped 59/151: His Wife, The Painter
# Scraped 60/151: My Father
# Scraped 61/151: Paris
# Scraped 62/151: My First Affair With That Older Woman
# Scraped 63/151: My Groupie
# Scraped 64/151: Writing
# Scraped 65/151: Hot
# Scraped 66/151: Melancholia
# Scraped 67/151: Metamorphosis
# Scraped 68/151: Hello, How Are You?
# Scraped 69/151: Rain
# Scraped 70/151: Young In New Orleans
# Scraped 71/151: The Icecream People
# Scraped 72/151: The Crunch
# Scraped 73/151: Jane Icin (For Jane - In Turkish)
# Scraped 74/151: I Like Your Books
# Scraped 75/151: Shoes
# Scraped 76/151: Trapped
# Scraped 77/151: Poetry
# Scraped 78/151: It's Ours
# Scraped 79/151: Poetry Reading
# Scraped 80/151: So Now?
# Scraped 81/151: Gamblers All
# Scraped 82/151: Working Out
# Scraped 83/151: The Lucky Ones
# Scraped 84/151: Finished?
# Scraped 85/151: It Was Just A Little While Ago
# Scraped 86/151: My Computer
# Scraped 87/151: Show Biz
# Scraped 88/151: What A Writer
# Scraped 89/151: My Friend, The Parking Lot Attendant
# Scraped 90/151: Splash
# Scraped 91/151: Question And Answer
# Scraped 92/151: What Can We Do?
# Scraped 93/151: Three Oranges
# Scraped 94/151: Poem For My 43rd Birthday
# Scraped 95/151: Here I Am ...
# Scraped 96/151: Luck
# Scraped 97/151: No. 6
# Scraped 98/151: The Shoelace
# Scraped 99/151: The House
# Scraped 100/151: Crucifix In A Deathhand
# Scraped 101/151: Sleep
# Scraped 102/151: Trashcan Lives
# Scraped 103/151: On Going Back To The Street After Viewing An Art Show
# Scraped 104/151: Layover
# Scraped 105/151: Small Conversation In The Afternoon With John Fante
# Scraped 106/151: Short Order
# Scraped 107/151: The Great Slob
# Scraped 108/151: Revolt In The Ranks
# Scraped 109/151: These Things
# Scraped 110/151: True Story
# Scraped 111/151: Love &Amp Fame &Amp Death
# Scraped 112/151: Hooray Say The Roses
# Scraped 113/151: Something For The Touts, The Nuns, The Grocery Clerks, And You . . .
# Scraped 114/151: The Worst And The Best
# Scraped 115/151: Now
# Scraped 116/151: Out Of The Arm Of One Love...
# Scraped 117/151: The German Hotel
# Scraped 118/151: Somebody
# Scraped 119/151: One Thirty-Six A.M.
# Scraped 120/151: Hemingway Never Did This
# Scraped 121/151: This
# Scraped 122/151: Magical Mystery Tour
# Scraped 123/151: Rain Or Shine
# Scraped 124/151: The Blackbirds Are Rough Today
# Scraped 125/151: The Night I Was Going To Die
# Scraped 126/151: The Laughing Heart
# Scraped 127/151: Mama
# Scraped 128/151: The Meek Shall Inherit The Earth
# Scraped 129/151: Marina
# Scraped 130/151: The Sun Wields Mercy
# Scraped 131/151: The Shower
# Scraped 132/151: So You Want To Be A Writer
# Scraped 133/151: The Retreat
# Scraped 134/151: New Mexico
# Scraped 135/151: air and light and time and space
# Scraped 136/151: Gas
# Scraped 137/151: Goading The Muse
# Scraped 138/151: I Am Visited By An Editor And A Poet
# Scraped 139/151: German
# Scraped 140/151: The Japanese Wife
# Scraped 141/151: Hell Is A Lonely Place
# Scraped 142/151: The Last Days Of The Suicide Kid
# Scraped 143/151: The Trash Men
# Scraped 144/151: Trollius And Trellises
# Scraped 145/151: On The Fire Suicides Of The Buddhists
# Scraped 146/151: No help for that
# Scraped 147/151: My Cats
# Scraped 148/151: The Great Escape
# Scraped 149/151: For The Foxes
# Scraped 150/151: Beasts Bounding Through Time
# Scraped 151/151: A 340 Dollar Horse And A Hundred Dollar Whore
# Scraping completed for Charles Bukowski! Poems saved to 'charles_bukowski_poems.csv'.
# Scraping poems by Allen Ginsberg...
# Scraping page 1 of 5 for Allen Ginsberg...
# Scraping page 2 of 5 for Allen Ginsberg...
# Scraping page 3 of 5 for Allen Ginsberg...
# Scraping page 4 of 5 for Allen Ginsberg...
# Scraping page 5 of 5 for Allen Ginsberg...
# Scraped 1/48: A Supermarket In California
# Scraped 2/48: Father Death Blues
# Scraped 3/48: Five A.M.
# Scraped 4/48: Homework
# Scraped 5/48: Cosmopolitan Greetings
# Scraped 6/48: An Eastern Ballad
# Scraped 7/48: Hospital Window
# Scraped 8/48: Crossing Nation
# Scraped 9/48: Death & Fame
# Scraped 10/48: Cia Dope Calypso
# Scraped 11/48: Haiku (Never Published)
# Scraped 12/48: September On Jessore Road
# Scraped 13/48: Fourth Floor, Dawn, Up All Night Writing Letters
# Scraped 14/48: First Party At Ken Kesey's With Hell's Angels
# Scraped 15/48: Kaddish, Part I
# Scraped 16/48: Sunflower Sutra
# Scraped 17/48: My Sad Self
# Scraped 18/48: In Back Of The Real
# Scraped 19/48: An Asphodel
# Scraped 20/48: Feb. 29, 1958
# Scraped 21/48: 136 Syllables At Rocky Mountain Dharma Center
# Scraped 22/48: Song
# Scraped 23/48: The Terms In Which I Think Of Reality
# Scraped 24/48: Hum Bom!
# Scraped 25/48: Kral Majales (King Of May)
# Scraped 26/48: In The Baggage Room At Greyhound
# Scraped 27/48: Plutonian Ode
# Scraped 28/48: Wild Orphan
# Scraped 29/48: Making The Lion For All It's Got -- A Ballad
# Scraped 30/48: Velocity Of Money
# Scraped 31/48: Sphincter
# Scraped 32/48: Those Two
# Scraped 33/48: Kissass
# Scraped 34/48: The Lion For Real
# Scraped 35/48: Understand That This Is A Dream
# Scraped 36/48: A Desolation
# Scraped 37/48: Footnote To Howl
# Scraped 38/48: Cezanne's Ports
# Scraped 39/48: Transcription Of Organ Music
# Scraped 40/48: On The Conduct Of The World Seeking Beauty Against Government
# Scraped 41/48: Mugging (I)
# Scraped 42/48: Nagasaki Days
# Scraped 43/48: War Profit Litany
# Scraped 44/48: Psalm Iv
# Scraped 45/48: Wales Visitation
# Scraped 46/48: To Aunt Rose
# Scraped 47/48: Paterson
# Scraped 48/48: The Blue Angel
# Scraping completed for Allen Ginsberg! Poems saved to 'allen_ginsberg_poems.csv'.
# Scraping poems by Jack Kerouac...
# Scraping page 1 of 3 for Jack Kerouac...
# Scraping page 2 of 3 for Jack Kerouac...
# Scraping page 3 of 3 for Jack Kerouac...
# Scraped 1/27: Haiku (Birds Singing...)
# Scraped 2/27: Haiku (The Taste...)
# Scraped 3/27: Haiku (The Low Yellow...)
# Scraped 4/27: How To Meditate
# Scraped 5/27: Hitchhiker
# Scraped 6/27: Bowery Blues
# Scraped 7/27: Bus East
# Scraped 8/27: On Tears
# Scraped 9/27: 10th Chorus Mexico City Blues
# Scraped 10/27: In Vain
# Scraped 11/27: Daydreams For Ginsberg
# Scraped 12/27: Nebraska
# Scraped 13/27: 2nd Chorus Mexico City Blues
# Scraped 14/27: 149th Chorus
# Scraped 15/27: 211th Chorus
# Scraped 16/27: 1st Chorus Mexico City Blues
# Scraped 17/27: 241st Chorus
# Scraped 18/27: 4th Chorus Mexico City Blues
# Scraped 19/27: 3rd Chorus Mexico City Blues
# Scraped 20/27: One Flower
# Scraped 21/27: Trees
# Scraped 22/27: The Scripture Of The Golden Eternity
# Scraped 23/27: Snow In My Shoe
# Scraped 24/27: Tenorman
# Scraped 25/27: Haiku (Holding Up My)
# Scraped 26/27: The Taste
# Scraped 27/27: To Harpo Marx
# Scraping completed for Jack Kerouac! Poems saved to 'jack_kerouac_poems.csv'.
# Scraping poems by Lawrence Ferlinghetti...
# Scraping page 1 of 4 for Lawrence Ferlinghetti...
# Scraping page 2 of 4 for Lawrence Ferlinghetti...
# Scraping page 3 of 4 for Lawrence Ferlinghetti...
# Scraping page 4 of 4 for Lawrence Ferlinghetti...
# Scraped 1/33: The World Is A Beautiful Place
# Scraped 2/33: I Am Waiting
# Scraped 3/33: Constantly Risking Absurdity
# Scraped 4/33: Sometime During Eternity
# Scraped 5/33: The Plough Of Time
# Scraped 6/33: Don'T Let That Horse
# Scraped 7/33: Wild Dreams Of A New Beginning
# Scraped 8/33: Number 8
# Scraped 9/33: The Pennycandystore Beyond The El
# Scraped 10/33: Populist Manifesto No. 1
# Scraped 11/33: Baseball Canto
# Scraped 12/33: Oh You Gatherer
# Scraped 13/33: A Vast Confusion
# Scraped 14/33: Underwear
# Scraped 15/33: The Great Chinese Dragon
# Scraped 16/33: Number 20
# Scraped 17/33: An Elegy On The Death Of Kenneth Patchen
# Scraped 18/33: The Changing Light
# Scraped 19/33: Recipe For Happiness Khaborovsk Or Anyplace
# Scraped 20/33: Driving A Cardboard Automobile Without A License
# Scraped 21/33: Bird With Two Right Wings
# Scraped 22/33: Dove Sta Amore
# Scraped 23/33: History Of The Airplane
# Scraped 24/33: Seascape With Sun And Eagle
# Scraped 25/33: To The Oracle At Delphi
# Scraped 26/33: Away Above A Harborful
# Scraped 27/33: Autobiography
# Scraped 28/33: Dog
# Scraped 29/33: Poetry as Insurgent Art [I am signaling you through the flames]
# Scraped 30/33: People Getting Divorced
# Scraped 31/33: [The Wounded Wilderness of Morris Graves]
# Scraped 32/33: In Goya's Greatest Scenes We Seem to See . . .
# Scraped 33/33: London Crossfigured
# Scraping completed for Lawrence Ferlinghetti! Poems saved to 'lawrence_ferlinghetti_poems.csv'.
# Scraping poems by Sylvia Plath...
# Scraping page 1 of 25 for Sylvia Plath...
# Scraping page 2 of 25 for Sylvia Plath...
# Scraping page 3 of 25 for Sylvia Plath...
# Scraping page 4 of 25 for Sylvia Plath...
# Scraping page 5 of 25 for Sylvia Plath...
# Scraping page 6 of 25 for Sylvia Plath...
# Scraping page 7 of 25 for Sylvia Plath...
# Scraping page 8 of 25 for Sylvia Plath...
# Scraping page 9 of 25 for Sylvia Plath...
# Scraping page 10 of 25 for Sylvia Plath...
# Scraping page 11 of 25 for Sylvia Plath...
# Scraping page 12 of 25 for Sylvia Plath...
# Scraping page 13 of 25 for Sylvia Plath...
# Scraping page 14 of 25 for Sylvia Plath...
# Scraping page 15 of 25 for Sylvia Plath...
# Scraping page 16 of 25 for Sylvia Plath...
# Scraping page 17 of 25 for Sylvia Plath...
# Scraping page 18 of 25 for Sylvia Plath...
# Scraping page 19 of 25 for Sylvia Plath...
# Scraping page 20 of 25 for Sylvia Plath...
# Scraping page 21 of 25 for Sylvia Plath...
# Scraping page 22 of 25 for Sylvia Plath...
# Scraping page 23 of 25 for Sylvia Plath...
# Scraping page 24 of 25 for Sylvia Plath...
# Scraping page 25 of 25 for Sylvia Plath...
# Scraped 1/250: Cinderella
# Scraped 2/250: Daddy
# Scraped 3/250: Lady Lazarus
# Scraped 4/250: A Birthday Present
# Scraped 5/250: Ariel
# Scraped 6/250: Mad Girl's Love Song
# Scraped 7/250: Metaphors
# Scraped 8/250: Mirror
# Scraped 9/250: Child
# Scraped 10/250: A Life
# Scraped 11/250: April 18
# Scraped 12/250: Blackberrying
# Scraped 13/250: Insomniac
# Scraped 14/250: Aftermath
# Scraped 15/250: Cut
# Scraped 16/250: Balloons
# Scraped 17/250: I Am Vertical
# Scraped 18/250: Black Rook In Rainy Weather
# Scraped 19/250: Among The Narcissi
# Scraped 20/250: Tulips
# Scraped 21/250: Edge
# Scraped 22/250: Mushrooms
# Scraped 23/250: The Rival
# Scraped 24/250: An Appearance
# Scraped 25/250: By Candlelight
# Scraped 26/250: You'Re
# Scraped 27/250: A Lesson In Vengeance
# Scraped 28/250: Never Try To Trick Me With A Kiss
# Scraped 29/250: Crossing The River
# Scraped 30/250: Apprehensions
# Scraped 31/250: Morning Song
# Scraped 32/250: Conversation Among The Ruins
# Scraped 33/250: Lesbos
# Scraped 34/250: Wuthering Heights
# Scraped 35/250: Jilted
# Scraped 36/250: Contusion
# Scraped 37/250: Stillborn
# Scraped 38/250: Death &Amp Co.
# Scraped 39/250: Winter Trees
# Scraped 40/250: Monologue At 3 Am
# Scraped 41/250: Poppies In July
# Scraped 42/250: The Applicant
# Scraped 43/250: The Colossus
# Scraped 44/250: Love Letter
# Scraped 45/250: Berck-Plage
# Scraped 46/250: On Looking Into The Eyes Of A Demon Lover
# Scraped 47/250: Kindness
# Scraped 48/250: Medusa
# Scraped 49/250: In Plaster
# Scraped 50/250: The Moon And The Yew Tree
# Scraped 51/250: Words
# Scraped 52/250: Spinster
# Scraped 53/250: Elm
# Scraped 54/250: Mystic
# Scraped 55/250: Crossing The Water
# Scraped 56/250: Sow
# Scraped 57/250: Bucolics
# Scraped 58/250: Fever 103 Deg.
# Scraped 59/250: Years
# Scraped 60/250: Last Words
# Scraped 61/250: The Night Dances
# Scraped 62/250: Sheep In Fog
# Scraped 63/250: Lorelei
# Scraped 64/250: Southern Sunrise
# Scraped 65/250: Pursuit
# Scraped 66/250: The Arrival Of The Bee Box
# Scraped 67/250: Dialogue Between Ghost And Priest
# Scraped 68/250: Snakecharmer
# Scraped 69/250: Paralytic
# Scraped 70/250: Getting There
# Scraped 71/250: The Other
# Scraped 72/250: Face Lift
# Scraped 73/250: Stings
# Scraped 74/250: Letter In November
# Scraped 75/250: Gigolo
# Scraped 76/250: Full Fathom Five
# Scraped 77/250: Poppies In October
# Scraped 78/250: The Dead
# Scraped 79/250: Night Shift
# Scraped 80/250: Mary's Song
# Scraped 81/250: Three Women
# Scraped 82/250: Perseus
# Scraped 83/250: Electra On Azalea Path
# Scraped 84/250: Poems, Potatoes
# Scraped 85/250: Leaving Early
# Scraped 86/250: The Bee Meeting
# Scraped 87/250: Virgin In A Tree
# Scraped 88/250: Sleepers
# Scraped 89/250: Fiesta Melons
# Scraped 90/250: The Thin People
# Scraped 91/250: Vanity Fair
# Scraped 92/250: The Swarm
# Scraped 93/250: Faun
# Scraped 94/250: Tale Of A Tub
# Scraped 95/250: The Manor Garden
# Scraped 96/250: The Munich Mannequins
# Scraped 97/250: The Sleepers
# Scraped 98/250: The Disquieting Muses
# Scraped 99/250: The Eye-Mote
# Scraped 100/250: Sleep In The Mojave Desert
# Scraped 101/250: The Queen's Complaint
# Scraped 102/250: Two Views Of A Cadaver Room
# Scraped 103/250: Goatsucker
# Scraped 104/250: Polly's Tree
# Scraped 105/250: Resolve
# Scraped 106/250: The Other Two
# Scraped 107/250: Nick And The Candlestick
# Scraped 108/250: Two Campers In Cloud Country
# Scraped 109/250: Two Sisters Of Persephone
# Scraped 110/250: Strumpet Song
# Scraped 111/250: The Couriers
# Scraped 112/250: Purdah
# Scraped 113/250: Wintering
# Scraped 114/250: Totem
# Scraped 115/250: Lyonnesse
# Scraped 116/250: The Bull Of Bendylaw
# Scraped 117/250: All The Dead Dears
# Scraped 118/250: Landowners
# Scraped 119/250: Prospect
# Scraped 120/250: A Winter Ship
# Scraped 121/250: A Sorcerer Bids Farewell To Seem
# Scraped 122/250: Winter Landscape, With Rooks
# Scraped 123/250: Sculptor
# Scraped 124/250: Metaphors
# Scraped 125/250: Love Is A Parallax
# Scraped 126/250: Dirge For A Joker
# Scraped 127/250: Family Reunion
# Scraped 128/250: Owl
# Scraped 129/250: Female Author
# Scraped 130/250: Childless Woman
# Scraped 131/250: Witch Burning
# Scraped 132/250: Lament
# Scraped 133/250: Magi
# Scraped 134/250: To A Jilted Lover
# Scraped 135/250: The Jailer
# Scraped 136/250: Candles
# Scraped 137/250: The Stones
# Scraped 138/250: The Hanging Man
# Scraped 139/250: Aquatic Nocturne
# Scraped 140/250: Yadwigha, On A Red Couch, Among Lillies
# Scraped 141/250: Burning The Letters
# Scraped 142/250: I Want, I Want
# Scraped 143/250: Man In Black
# Scraped 144/250: The Ghost's Leavetaking
# Scraped 145/250: Amnesiac
# Scraped 146/250: The Courage Of Shutting-Up
# Scraped 147/250: Mary's Song
# Scraped 148/250: Soliloquy Of The Solipsist
# Scraped 149/250: Channel Crossing
# Scraped 150/250: Gulliver
# Scraped 151/250: Doomsday
# Scraped 152/250: To Eva Descending The Stair
# Scraped 153/250: Moonrise
# Scraped 154/250: Waking In Winter
# Scraped 155/250: Ouija
# Scraped 156/250: The Ravaged Face
# Scraped 157/250: April Aubade
# Scraped 158/250: The Beast
# Scraped 159/250: Doom Of Exiles
# Scraped 160/250: Face Lift
# Scraped 161/250: The Rabbit Catcher
# Scraped 162/250: Denouement Villanelle
# Scraped 163/250: Eavesdropper
# Scraped 164/250: The Trial Of A Man
# Scraped 165/250: The Beekeeper's Daughter
# Scraped 166/250: Parliament Hill Fields
# Scraped 167/250: The Surgeon At 2 A.M.
# Scraped 168/250: Private Ground
# Scraped 169/250: Recantation
# Scraped 170/250: Flute Notes From A Reedy Pond
# Scraped 171/250: Memoirs Of A Spinach-Picker
# Scraped 172/250: On The Difficulty Of Conjuring Up A Dryad
# Scraped 173/250: Maenad
# Scraped 174/250: Suicide Off Egg Rock
# Scraped 175/250: The Princess And The Goblins
# Scraped 176/250: The Companionable Ills
# Scraped 177/250: Letter To A Purist
# Scraped 178/250: Magnolia Shoals
# Scraped 179/250: Notes To A Neophyte
# Scraped 180/250: Pheasant
# Scraped 181/250: Sonnet : To Eva
# Scraped 182/250: Medallion
# Scraped 183/250: Miss Drake Proceeds To Supper
# Scraped 184/250: Brasilia
# Scraped 185/250: Song For A Summer's Day
# Scraped 186/250: Widow
# Scraped 187/250: Little Fugue
# Scraped 188/250: The Babysitters
# Scraped 189/250: Point Shirley
# Scraped 190/250: The Goring
# Scraped 191/250: Black Pine Tree In An Orange Light
# Scraped 192/250: Dark Wood, Dark Water
# Scraped 193/250: Hardcastle Crags
# Scraped 194/250: Firesong
# Scraped 195/250: Watercolor Of Grantchester Meadows
# Scraped 196/250: Circus in Three Rings
# Scraped 197/250: Stopped Dead
# Scraped 198/250: The Fearful
# Scraped 199/250: For A Fatherless Son
# Scraped 200/250: The Everlasting Monday
# Scraped 201/250: Green Rock, Winthrop Bay
# Scraped 202/250: Frog Autumn
# Scraped 203/250: Dark House
# Scraped 204/250: The Hermit At Outermost House
# Scraped 205/250: Child's Park Stones
# Scraped 206/250: Who
# Scraped 207/250: The Tour
# Scraped 208/250: The Lady And The Earthenware Head
# Scraped 209/250: Crystal Gazer
# Scraped 210/250: Maudlin
# Scraped 211/250: Departure
# Scraped 212/250: Stars Over The Dordogne
# Scraped 213/250: Fable Of The Rhododendron Stealers
# Scraped 214/250: The Death Of Myth-Making
# Scraped 215/250: Heavy Woman
# Scraped 216/250: Words Heard, By Accident, Over The Phone
# Scraped 217/250: Alicante Lullaby
# Scraped 218/250: Gold Mouths Cry
# Scraped 219/250: Finisterre
# Scraped 220/250: Thalidomide
# Scraped 221/250: The Snowman On The Moor
# Scraped 222/250: Battle-Scene From The Comic Operatic Fantasy The Seafarer
# Scraped 223/250: The Manor Garden
# Scraped 224/250: Ode For Ted
# Scraped 225/250: The Sleepers
# Scraped 226/250: Bluebeard
# Scraped 227/250: The Burnt-Out Spa
# Scraped 228/250: Touch-And-Go
# Scraped 229/250: Verbal Calisthenics
# Scraped 230/250: Prologue To Spring
# Scraped 231/250: Rhyme
# Scraped 232/250: The Glutton
# Scraped 233/250: The Times Are Tidy
# Scraped 234/250: The Shrike
# Scraped 235/250: 'Célibataire'
# Scraped 236/250: The Detective
# Scraped 237/250: Spider
# Scraped 238/250: The Great Carbuncle
# Scraped 239/250: Blue Moles
# Scraped 240/250: Event
# Scraped 241/250: Terminal
# Scraped 242/250: Whitsun
# Scraped 243/250: Mussel Hunter At Rock Harbor
# Scraped 244/250: Natural History
# Scraped 245/250: The Net-Menders
# Scraped 246/250: On Deck
# Scraped 247/250: Incommunicado
# Scraped 248/250: Yaddo : The Grand Manor
# Scraped 249/250: New Year On Dartmoor
# Scraped 250/250: In Midas' Country
# Scraping completed for Sylvia Plath! Poems saved to 'sylvia_plath_poems.csv'.
# All poets have been scraped successfully!

# %% [markdown]
# # Joing the csv files

# %%
# Load all CSV files
bukowski = pd.read_csv('charles_bukowski_poems.csv')
ginsberg = pd.read_csv('allen_ginsberg_poems.csv')
kerouac = pd.read_csv('jack_kerouac_poems.csv')
ferlinghetti = pd.read_csv('lawrence_ferlinghetti_poems.csv')
plath = pd.read_csv('sylvia_plath_poems.csv')

# Combine the data into a single DataFrame
all_poems_df = pd.concat([bukowski, ginsberg, kerouac, ferlinghetti, plath], ignore_index=True)

# Basic text cleaning
def clean_poem(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'[^a-z\s]', '', text)  # Remove special characters and punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Replace multiple spaces with a single space
    return text

# Apply the cleaning function to the 'Content' column
all_poems_df['Cleaned_Content'] = all_poems_df['Content'].apply(clean_poem)

# Save the cleaned dataset
all_poems_df.to_csv('all_poets_cleaned_poems.csv', index=False, encoding='utf-8')
print("Combined and cleaned dataset saved as 'all_poets_cleaned_poems.csv'.")
# Out:
# Combined and cleaned dataset saved as 'all_poets_cleaned_poems.csv'.
